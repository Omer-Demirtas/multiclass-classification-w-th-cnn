# %%
# Global Variables

train_dir = "train"
test_dir = "test"
model_dir = "./model/"

class_numbers = [4,11,33,52,77,82]
class_names = ['/beaver','/boy','/forest','/oak_tree','/snail','/sunflower']

# to access varaibles in other files
# %store test_dir
# %store train_dir
# %store model_dir

# %store class_names
# %store class_numbers

# %store -r X_train
# %store -r y_train
# %store -r X_test 
# %store -r y_test
# Out:
# Stored 'test_dir' (str)
# Stored 'train_dir' (str)
# Stored 'model_dir' (str)
# Stored 'class_names' (list)
# Stored 'class_numbers' (list)

# %%
# Import project parts

# %run ./data_properaing.ipynb
# %run ./data_virtualzing.ipynb
# %run ./model.ipynb

# %%
load_data()

# %%
handle_data_file_structure()
# Out:
# train/beaver konumunda dosya vardır kontrol ediniz
#
# train/boy konumunda dosya vardır kontrol ediniz
#
# train/forest konumunda dosya vardır kontrol ediniz
#
# train/oak_tree konumunda dosya vardır kontrol ediniz
#
# train/snail konumunda dosya vardır kontrol ediniz
#
# train/sunflower konumunda dosya vardır kontrol ediniz
#
# test/beaver konumunda dosya vardır kontrol ediniz
#
# test/boy konumunda dosya vardır kontrol ediniz
#
# test/forest konumunda dosya vardır kontrol ediniz
#
# test/oak_tree konumunda dosya vardır kontrol ediniz
#
# test/snail konumunda dosya vardır kontrol ediniz
#
# test/sunflower konumunda dosya vardır kontrol ediniz

# %%
show_samples()

# %%
model = create_model()
# Out:
# /home/omer/anaconda3/envs/vscode/lib/python3.9/site-packages/keras/optimizers/legacy/adamax.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
model_summary(model)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 128)         147584
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dropout_2 (Dropout)         (None, 8192)              0
#
#  dense_3 (Dense)             (None, 256)               2097408
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dense_5 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 2,451,750
# Trainable params: 2,451,750
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = fit_model(model)
# Out:
# Found 3000 images belonging to 6 classes.
# Found 600 images belonging to 6 classes.
# Epoch 1/2
# /tmp/ipykernel_16856/3093547917.py:23: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator,
# 2024-05-05 12:35:22.748929: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 150/150 [==============================] - ETA: 0s - loss: 1.6779 - acc: 0.2523
# 2024-05-05 12:35:48.074184: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 150/150 [==============================] - 27s 173ms/step - loss: 1.6779 - acc: 0.2523 - val_loss: 1.4964 - val_acc: 0.3200
# Epoch 2/2
# 150/150 [==============================] - 27s 180ms/step - loss: 1.4996 - acc: 0.3130 - val_loss: 1.4109 - val_acc: 0.3567
# acc = 0.31299999356269836
# val_acc =  0.3566666543483734
# loss = 1.4996126890182495
# val_loss = 1.4109257459640503

# %%
model_summary(model)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 128)         147584
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dropout_2 (Dropout)         (None, 8192)              0
#
#  dense_3 (Dense)             (None, 256)               2097408
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dense_5 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 2,451,750
# Trainable params: 2,451,750
# Non-trainable params: 0
# _________________________________________________________________
