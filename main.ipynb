# %%
# Global Variables

EPOCH = 60
STEPS_PER_EPOCH = 150
VALIDATION_STEPS = 30

test_dir = "test"
train_dir = "train"
model_dir = "./model/"

class_numbers = [19, 22, 37, 49, 61, 86, 90]
class_names = ['/cattle','/clock','/house','/mountain','/plate','/telephone', '/train']

# to access varaibles in other files
# %store EPOCH
# %store STEPS_PER_EPOCH
# %store VALIDATION_STEPS

# %store test_dir
# %store train_dir
# %store model_dir

# %store class_names
# %store class_numbers

# %store -r X_train
# %store -r y_train
# %store -r X_test 
# %store -r y_test
# Out:
# Stored 'test_dir' (str)
# Stored 'train_dir' (str)
# Stored 'model_dir' (str)
# Stored 'class_names' (list)
# Stored 'class_numbers' (list)

# %%
# Import project parts

# %run ./data_properaing.ipynb
# %run ./data_virtualzing.ipynb
# %run ./model.ipynb

# %%
load_data()

# %%
handle_data_file_structure()
# Out:
# train/cattle konumunda dosya vardır kontrol ediniz
#
# train/clock konumunda dosya vardır kontrol ediniz
#
# train/house konumunda dosya vardır kontrol ediniz
#
# train/mountain konumunda dosya vardır kontrol ediniz
#
# train/plate konumunda dosya vardır kontrol ediniz
#
# train/telephone konumunda dosya vardır kontrol ediniz
#
# train/train konumunda dosya vardır kontrol ediniz
#
# test/cattle konumunda dosya vardır kontrol ediniz
#
# test/clock konumunda dosya vardır kontrol ediniz
#
# test/house konumunda dosya vardır kontrol ediniz
#
# test/mountain konumunda dosya vardır kontrol ediniz
#
# test/plate konumunda dosya vardır kontrol ediniz
#
# test/telephone konumunda dosya vardır kontrol ediniz
#
# test/train konumunda dosya vardır kontrol ediniz

# %%
show_samples()

# %%
model = create_model()

# %%
model_summary(model)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_12 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_4 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_5 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 128)         147584
#
#  flatten_2 (Flatten)         (None, 8192)              0
#
#  dropout_4 (Dropout)         (None, 8192)              0
#
#  dense_6 (Dense)             (None, 256)               2097408
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 256)               65792
#
# ...

# %%
hist = fit_model(model)
# Out:
# Found 3500 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.
# Epoch 1/2
# /tmp/ipykernel_22177/369523174.py:22: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator,
# 2024-05-05 14:11:34.142248: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 150/150 [==============================] - ETA: 0s - loss: 1.9642 - acc: 0.2203
# ...

# %%
model_summary(model)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_12 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_4 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_5 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 128)         147584
#
#  flatten_2 (Flatten)         (None, 8192)              0
#
#  dropout_4 (Dropout)         (None, 8192)              0
#
#  dense_6 (Dense)             (None, 256)               2097408
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 256)               65792
#
# ...
