# %%
# Global Variables

EPOCH = 30
STEPS_PER_EPOCH = 150
VALIDATION_STEPS = 30

test_dir = "test"
train_dir = "train"
model_dir = "./model/"

class_numbers = [19, 22, 37, 49, 61, 86, 90]
class_names = ['/cattle','/clock','/house','/mountain','/plate','/telephone', '/train']

# to access varaibles in other files
# %store EPOCH
# %store STEPS_PER_EPOCH
# %store VALIDATION_STEPS

# %store test_dir
# %store train_dir
# %store model_dir

# %store class_names
# %store class_numbers

# %store -r X_train
# %store -r y_train
# %store -r X_test 
# %store -r y_test
# Out:
# Stored 'EPOCH' (int)
# Stored 'STEPS_PER_EPOCH' (int)
# Stored 'VALIDATION_STEPS' (int)
# Stored 'test_dir' (str)
# Stored 'train_dir' (str)
# Stored 'model_dir' (str)
# Stored 'class_names' (list)
# Stored 'class_numbers' (list)

# %%
# Import project parts

# %run ./data_properaing.ipynb
# %run ./data_virtualzing.ipynb
# %run ./model.ipynb

# %%
load_data()

# %%
handle_data_file_structure()
# Out:
# train/cattle konumunda dosya vardır kontrol ediniz
#
# train/clock konumunda dosya vardır kontrol ediniz
#
# train/house konumunda dosya vardır kontrol ediniz
#
# train/mountain konumunda dosya vardır kontrol ediniz
#
# train/plate konumunda dosya vardır kontrol ediniz
#
# train/telephone konumunda dosya vardır kontrol ediniz
#
# train/train konumunda dosya vardır kontrol ediniz
#
# test/cattle konumunda dosya vardır kontrol ediniz
#
# test/clock konumunda dosya vardır kontrol ediniz
#
# test/house konumunda dosya vardır kontrol ediniz
#
# test/mountain konumunda dosya vardır kontrol ediniz
#
# test/plate konumunda dosya vardır kontrol ediniz
#
# test/telephone konumunda dosya vardır kontrol ediniz
#
# test/train konumunda dosya vardır kontrol ediniz

# %%
show_samples()

# %%
model = create_model()

# %%
model_summary(model)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 32, 32, 64)        1792
#
#  max_pooling2d_13 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_14 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 8, 8, 128)         73856
#
#  max_pooling2d_15 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 4, 4, 128)         147584
#
#  flatten_5 (Flatten)         (None, 2048)              0
#
#  dropout_10 (Dropout)        (None, 2048)              0
#
#  dense_15 (Dense)            (None, 256)               524544
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 256)               65792
#
#  dense_17 (Dense)            (None, 7)                 1799
#
# =================================================================
# Total params: 852,295
# Trainable params: 852,295
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = fit_model(model)
# Out:
# Found 3500 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.
# Epoch 1/30
# 2024-05-05 20:38:36.310942: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
#
# 150/150 [==============================] - 18s 120ms/step - loss: 0.7543 - acc: 0.7157 - val_loss: 0.7737 - val_acc: 0.7183
# Epoch 20/30
# 150/150 [==============================] - 18s 117ms/step - loss: 0.7541 - acc: 0.7107 - val_loss: 0.8220 - val_acc: 0.6900
# Epoch 21/30
# 150/150 [==============================] - 18s 121ms/step - loss: 0.7195 - acc: 0.7277 - val_loss: 0.7780 - val_acc: 0.7033
# Epoch 22/30
# 150/150 [==============================] - 17s 113ms/step - loss: 0.6995 - acc: 0.7370 - val_loss: 0.8137 - val_acc: 0.7167
# Epoch 23/30
# 150/150 [==============================] - 19s 125ms/step - loss: 0.7053 - acc: 0.7357 - val_loss: 0.8496 - val_acc: 0.6883
# Epoch 24/30
# 150/150 [==============================] - 19s 124ms/step - loss: 0.6494 - acc: 0.7510 - val_loss: 0.7793 - val_acc: 0.7083
# Epoch 25/30
# 150/150 [==============================] - 17s 116ms/step - loss: 0.6563 - acc: 0.7470 - val_loss: 0.8052 - val_acc: 0.7217
# Epoch 26/30
# 150/150 [==============================] - 17s 114ms/step - loss: 0.6394 - acc: 0.7583 - val_loss: 0.8377 - val_acc: 0.6817
# Epoch 27/30
# 150/150 [==============================] - 21s 138ms/step - loss: 0.6126 - acc: 0.7750 - val_loss: 0.7338 - val_acc: 0.7483
# Epoch 28/30
# 150/150 [==============================] - 18s 120ms/step - loss: 0.6015 - acc: 0.7733 - val_loss: 0.8012 - val_acc: 0.7133
# Epoch 29/30
# 150/150 [==============================] - 18s 123ms/step - loss: 0.5930 - acc: 0.7720 - val_loss: 0.8083 - val_acc: 0.6883
# Epoch 30/30
# 150/150 [==============================] - 17s 110ms/step - loss: 0.5667 - acc: 0.7900 - val_loss: 0.7830 - val_acc: 0.7100
# acc = 0.7900000214576721
# val_acc =  0.7099999785423279
# loss = 0.5666860938072205
# val_loss = 0.7829755544662476

# %%
model_summary(model)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 32, 32, 64)        1792
#
#  max_pooling2d_13 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_14 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 8, 8, 128)         73856
#
#  max_pooling2d_15 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 4, 4, 128)         147584
#
#  flatten_5 (Flatten)         (None, 2048)              0
#
#  dropout_10 (Dropout)        (None, 2048)              0
#
#  dense_15 (Dense)            (None, 256)               524544
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 256)               65792
#
#  dense_17 (Dense)            (None, 7)                 1799
#
# =================================================================
# Total params: 852,295
# Trainable params: 852,295
# Non-trainable params: 0
# _________________________________________________________________
